# %%
import orangebook as ob

# %%
ob.be('Ru')
# Out:
# 44 Ru:
# 	 1s	 22117.0
# 	 2s	 3224.0
# 	 2p1/2	 2967.0
# 	 2p3/2	 2838.0
# 	 3s	 586.1
# 	 3p1/2	 483.5
# 	 3p3/2	 461.4
# 	 3d3/2	 284.2
# 	 3d5/2	 280.0
# 	 4s	 75.0
# 	 4p1/2	 46.3
# 	 4p3/2	 43.2

# %%
ob.be(12)
# Out:
# 12 Mg:
# 	 1s	 1303.0
# 	 2s	 88.7
# 	 2p1/2	 49.78
# 	 2p3/2	 49.5

# %%
ob.find?
# Out:
# Signature: ob.find(energy, delta=5.0, notation='orbital')
# Docstring:
# prints atomic number, element, edge and energy for all edges within the range: energy - delta and energy + delta
# notation: 'edge' or 'orbital'
# File:      ~/.conda/envs/bluesky_2022_2/lib/python3.9/site-packages/orangebook/orangebook.py
# Type:      function

# %%
ob.find(1220)
# Out:
# Energy range: 1215.0 - 1225.0
#
# 32 Ge:
#    2p3/2 1217.0
#
# 64 Gd:
#    3d3/2 1221.9

# %%
ob.find(100,2)
# Out:
# Energy range: 98 - 102
#
# 14 Si:
#    2p1/2 99.82
#    2p3/2 99.42
#
# 27 Co:
#    3s 101.0
#
# 31 Ga:
#    3p3/2 100.0
#
# 78 Pt:
#    5s 101.7
#
# 80 Hg:
#    4f7/2 99.9

# %%
ob.xps('Ag')
